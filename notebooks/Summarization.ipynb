# %% [markdown]
# # Summarization of seed-level factor results
#
# This notebook reads `summary_seed_*.json` files from seed-level runs, counts recurrent top CBCL items by factor, builds an item-by-factor frequency matrix, maps items to Spectrum-6/Spectrum-5 categories, and saves summary tables and figures to `../output`.

# %% [markdown]
# ## 1. Imports and configuration

# %%
import os
import re
import json
from collections import Counter, defaultdict
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Number of latent factors used in this summary notebook.
n_components = 5
n_componets = n_components

# Input directory containing seed_1, seed_2, ... folders.
BASE_DIR = r"G:\ABCD\script/trail\output\seed_run_500\seed_runs"

# Output directory for all tables and figures generated by this notebook.
OUTPUT_DIR = Path("../output").resolve()
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

CSV_PATH = OUTPUT_DIR / "factor_top_items_across_seeds.csv"

summary_results = {
    "config": {
        "n_components": n_components,
        "base_dir": BASE_DIR,
        "output_dir": str(OUTPUT_DIR),
        "csv_path": str(CSV_PATH),
    }
}

print("Input BASE_DIR:", BASE_DIR)
print("Output directory:", OUTPUT_DIR)

# %% [markdown]
# ## 2. Helper functions

# %%
def normalize_item_name(name: str) -> str:
    """Clean item text to avoid duplicates caused by spacing or line-break differences."""
    return " ".join(str(name).split())


def standardize_factor_name(name: str) -> str:
    """Convert common component labels to Factor1, Factor2, ..., FactorN."""
    text = str(name).strip()
    match = re.search(r"(\d+)", text)
    if match:
        factor_id = int(match.group(1))
        if 1 <= factor_id <= n_components:
            return f"Factor{factor_id}"
    return text.replace(" ", "")


def iter_seed_summary_files(base_dir: str):
    """Yield seed summary paths from seed_* folders."""
    if not os.path.isdir(base_dir):
        raise FileNotFoundError(f"BASE_DIR does not exist: {base_dir}")

    for folder in sorted(os.listdir(base_dir)):
        folder_path = os.path.join(base_dir, folder)
        if not os.path.isdir(folder_path):
            continue
        if not folder.startswith("seed_"):
            continue

        seed_id = folder.split("_", 1)[-1]
        summary_filename = f"summary_seed_{seed_id}.json"
        summary_path = os.path.join(folder_path, summary_filename)
        yield folder, seed_id, summary_path


def collect_top_items_across_seeds(base_dir: str) -> tuple[pd.DataFrame, dict]:
    """Count how many seed runs contain each top item for each factor."""
    item_seed_count_by_factor = defaultdict(Counter)
    num_seeds = 0
    missing_files = []
    read_errors = []

    for _, _, summary_path in iter_seed_summary_files(base_dir):
        if not os.path.exists(summary_path):
            missing_files.append(summary_path)
            continue

        try:
            with open(summary_path, "r", encoding="utf-8") as f:
                data = json.load(f)
        except Exception as exc:
            read_errors.append((summary_path, repr(exc)))
            continue

        num_seeds += 1
        top_items = data.get("cca", {}).get("top_items", {})

        for factor_name, items_list in top_items.items():
            factor_name = standardize_factor_name(factor_name)
            seen_items_this_seed_factor = set()
            for item_info in items_list:
                raw_name = (item_info.get("item") or "").strip()
                if not raw_name:
                    continue
                seen_items_this_seed_factor.add(normalize_item_name(raw_name))

            for item in seen_items_this_seed_factor:
                item_seed_count_by_factor[factor_name][item] += 1

    rows = []
    factor_order = [f"Factor{i + 1}" for i in range(n_components)]
    sorted_factors = sorted(
        item_seed_count_by_factor.keys(),
        key=lambda x: factor_order.index(x) if x in factor_order else len(factor_order),
    )
    for factor_name in sorted_factors:
        for item, count in item_seed_count_by_factor[factor_name].most_common():
            rows.append({"Factor": factor_name, "item": item, "seeds_count": count})

    df_counts = pd.DataFrame(rows, columns=["Factor", "item", "seeds_count"])
    metadata = {
        "num_seed_files_processed": num_seeds,
        "n_missing_files": len(missing_files),
        "missing_files": missing_files,
        "n_read_errors": len(read_errors),
        "read_errors": read_errors,
    }
    return df_counts, metadata

# %% [markdown]
# ## 3. Aggregate top items across seed runs
#
# The output table is saved as `../output/factor_top_items_across_seeds.csv`.

# %%
df_top_items, seed_metadata = collect_top_items_across_seeds(BASE_DIR)

if df_top_items.empty:
    raise ValueError(
        "No top-item records were collected. Check whether BASE_DIR contains seed_* folders with summary_seed_*.json files."
    )

df_top_items.to_csv(CSV_PATH, index=False, encoding="utf-8-sig")

summary_results["top_items_across_seeds"] = {
    "table": df_top_items,
    "metadata": seed_metadata,
    "output_csv": str(CSV_PATH),
}

print(f"Total summary files successfully processed: {seed_metadata['num_seed_files_processed']}")
print(f"Saved consolidated table to: {CSV_PATH}")

if seed_metadata["n_missing_files"]:
    print("\nMissing summary files detected. First 10 paths:")
    for path in seed_metadata["missing_files"][:10]:
        print("  ", path)
    if seed_metadata["n_missing_files"] > 10:
        print(f"... and {seed_metadata['n_missing_files'] - 10} more not shown")

if seed_metadata["n_read_errors"]:
    print("\nRead errors detected. First 10 errors:")
    for path, err in seed_metadata["read_errors"][:10]:
        print("  ", path, "|", err)

df_top_items.head()

# %% [markdown]
# ## 4. Item × Factor frequency matrix and contour terrain map
#
# The figure is saved to `../output/frequency_contour_terrain.png`.

# %%
def build_frequency_matrix(df_counts: pd.DataFrame, n_components: int) -> pd.DataFrame:
    """Build the item × Factor seed-frequency matrix."""
    df_counts = df_counts.copy()
    df_counts["Factor"] = df_counts["Factor"].map(standardize_factor_name)

    freq_mat = df_counts.pivot_table(
        index="item",
        columns="Factor",
        values="seeds_count",
        fill_value=0,
    )

    expected_cols = [f"Factor{i + 1}" for i in range(n_components)]
    existing_expected_cols = [col for col in expected_cols if col in freq_mat.columns]
    if not existing_expected_cols:
        raise ValueError(f"None of the expected Factor columns were found: {expected_cols}")

    freq_mat = freq_mat.reindex(columns=expected_cols, fill_value=0)

    primary_factor = freq_mat.idxmax(axis=1)
    max_freq = freq_mat.max(axis=1)
    sort_info = pd.DataFrame({"primary_factor": primary_factor, "max_freq": max_freq}, index=freq_mat.index)
    sort_info = sort_info.sort_values(by=["primary_factor", "max_freq"], ascending=[True, False])
    return freq_mat.loc[sort_info.index]


def plot_frequency_contour(freq_sorted: pd.DataFrame, output_path: Path) -> Path:
    """Plot and save the item × Factor seed-frequency contour map."""
    z = freq_sorted.values
    n_items, n_factors = z.shape
    x = np.arange(n_factors)
    y = np.arange(n_items)
    X, Y = np.meshgrid(x, y)

    fig = plt.figure(figsize=(15, 20))
    contourf = plt.contourf(X, Y, z, levels=20, cmap="terrain")
    contour = plt.contour(X, Y, z, levels=20, colors="k", linewidths=0.3, alpha=0.6)
    plt.clabel(contour, fontsize=6, inline=True)

    plt.xticks(ticks=np.arange(n_factors), labels=list(freq_sorted.columns))

    step = max(1, n_items // 25)
    yticks = np.arange(0, n_items, step)
    yticklabels = [freq_sorted.index[i] for i in yticks]
    plt.yticks(yticks, yticklabels)

    plt.gca().invert_yaxis()
    plt.title(f"Contour terrain map of item frequencies across factors ({int(z.max())} max seed count)")
    plt.xlabel("Factors")
    plt.ylabel("CBCL items sorted by primary factor and frequency")
    plt.colorbar(contourf, label="Seed frequency")
    plt.tight_layout()
    plt.savefig(output_path, dpi=300, bbox_inches="tight")
    plt.show()
    return output_path


freq_sorted = build_frequency_matrix(df_top_items, n_components=n_components)
contour_path = plot_frequency_contour(freq_sorted, OUTPUT_DIR / "frequency_contour_terrain.png")

summary_results["frequency_matrix"] = {
    "table": freq_sorted,
    "output_figure": str(contour_path),
}

print("Frequency matrix shape:", freq_sorted.shape)
print("Saved contour terrain map to:", contour_path)

# %% [markdown]
# ## 5. Rule-based Spectrum-6 and Spectrum-5 mapping

# %%
SPANISH_DIACRITICS = re.compile(r"[ÁÉÍÓÚÜÑáéíóúüñ]")
MOJIBAKE = re.compile(r"[√�]")


def normalize_space(s: str) -> str:
    return " ".join(str(s).split()).strip()


def strip_non_english_tail(s: str) -> str:
    """Keep the English stem before Spanish diacritics or mojibake symbols."""
    s = str(s)
    m1 = SPANISH_DIACRITICS.search(s)
    m2 = MOJIBAKE.search(s)
    cut = None
    if m1:
        cut = m1.start()
    if m2:
        cut = m2.start() if cut is None else min(cut, m2.start())
    if cut is not None:
        s = s[:cut]
    return normalize_space(s)


def item_for_match(raw: str) -> str:
    return strip_non_english_tail(raw).lower()


SPECTRA_6 = [
    "internalizing",
    "somatoform",
    "detachment",
    "thought disorder",
    "antagonism",
    "disinhibition",
]

RULES_6 = {
    "somatoform": [
        "bowel movements outside toilet", "constipated", "headache", "stomachache",
        "nausea", "vomiting", "vomit", "aches or pains", "aches", "pain",
        "problems with eyes", "rashes", "skin problems", "dizzy", "lightheaded",
        "gets hurt a lot", "accident prone", "overweight", "other (physical problems",
        "wets the bed", "wets self during the day",
    ],
    "thought disorder": [
        "can't get their mind off", "obsessions", "repeats certain acts", "compulsions",
        "hears sound or voices", "sees things that aren't there", "strange ideas",
        "strange behavior", "feels others are out to get them", "suspicious",
        "confused or seems to be in a fog", "in a fog", "stares blankly", "daydreams",
    ],
    "disinhibition": [
        "can't concentrate", "pay attention", "inattentive", "easily distracted",
        "can't sit still", "restless", "hyperactive", "impulsive", "acts without thinking",
        "fails to finish", "talks too much", "demands a lot of attention", "unusually loud",
        "poor school work", "poorly coordinated", "clumsy", "speech problem",
        "stores up too many things", "talks or walks in sleep",
    ],
    "antagonism": [
        "argues a lot", "gets in many fights", "threatens people", "physically attacks people",
        "temper tantrums", "hot temper", "screams a lot", "cruelty, bullying", "meanness to others",
        "cruel to animals", "teases a lot", "stubborn, sullen, or irritable", "disobedient",
        "breaks rules", "lying or cheating", "swearing", "obscene language", "steals at home",
        "steals outside the home", "vandalism", "destroys their own things",
        "destroys things belonging to their family or others", "sets fires", "runs away from home",
        "truancy", "skips school", "hangs around with others who get in trouble", "drinks alcohol",
        "smokes", "chews", "sniffs tobacco", "uses drugs", "plays with own sex parts in public",
        "plays with own sex parts too much", "sexual problems", "thinks about sex too much",
        "prefers being with older kids", "prefers being with younger kids",
    ],
    "detachment": [
        "would rather be alone", "withdrawn", "doesn't get involved with others", "refuses to talk",
        "secretive", "complains of loneliness", "too shy or timid", "not liked by other kids",
        "doesn't get along with other kids", "gets teased a lot", "there is very little they enjoy",
        "clings to adults or too dependent", "acts too young for their age", "bragging, boasting",
        "showing off or clowning", "easily jealous",
    ],
    "internalizing": [
        "worries", "nervous", "tense", "too fearful or anxious", "fears ",
        "fears going to school", "fears they might think or do something bad", "feels too guilty",
        "feels worthless or inferior", "cries a lot", "unhappy, sad, or depressed",
        "sudden changes in mood", "sulks a lot", "self-conscious or easily embarrassed",
        "nightmares", "trouble sleeping", "overtired", "doesn't eat well", "overeating",
        "talks about killing self", "deliberately harms self", "feels they have to be perfect",
        "feels or complains that no one loves them", "thumb-sucking", "bites fingernails",
        "whining", "wishes to be of opposite sex", "underactive, slow moving, or lacks energy",
        "feels dizzy or lightheaded",
    ],
}

PRIORITY_6 = [
    "somatoform",
    "thought disorder",
    "disinhibition",
    "antagonism",
    "detachment",
    "internalizing",
]

SPECTRA_5 = [
    "internalizing",
    "somatoform",
    "detachment",
    "neurodevelopmental",
    "externalizing",
]

MAP_6_TO_5 = {
    "internalizing": "internalizing",
    "somatoform": "somatoform",
    "detachment": "detachment",
    "thought disorder": "neurodevelopmental",
    "disinhibition": "neurodevelopmental",
    "antagonism": "externalizing",
}


def map_to_spectrum6(item_match: str) -> str:
    """Map a normalized item string to one of the six spectra; unmatched items are assigned to detachment."""
    for spec in PRIORITY_6:
        for kw in RULES_6.get(spec, []):
            if kw in item_match:
                return spec
    return "detachment"


def add_spectrum_mappings(df_counts: pd.DataFrame) -> pd.DataFrame:
    """Add normalized item text, Spectrum-6 mapping, and Spectrum-5 mapping."""
    df = df_counts.copy()
    df.columns = [c.strip() for c in df.columns]

    required = {"Factor", "item", "seeds_count"}
    missing = required - set(df.columns)
    if missing:
        raise ValueError(f"CSV missing columns: {missing}. Found: {df.columns.tolist()}")

    df["Factor"] = df["Factor"].map(standardize_factor_name)
    df["item"] = df["item"].astype(str)
    df["seeds_count"] = pd.to_numeric(df["seeds_count"], errors="coerce").fillna(0.0)
    df["item_match"] = df["item"].map(item_for_match)
    df["spectrum6"] = df["item_match"].map(map_to_spectrum6)
    df["spectrum5"] = df["spectrum6"].map(MAP_6_TO_5).fillna("detachment")
    return df

# %% [markdown]
# ## 6. Save item-level Spectrum mapping tables
#
# The item-level mapping outputs are saved under `../output`.

# %%
df_mapped = add_spectrum_mappings(df_top_items)

df_item6 = df_mapped[["Factor", "item", "spectrum6", "seeds_count"]].copy()
df_item5 = df_mapped[["Factor", "item", "spectrum5", "seeds_count"]].copy()

item6_path = OUTPUT_DIR / "items_to_spectrum6.csv"
item5_path = OUTPUT_DIR / "items_to_spectrum5.csv"

df_item6.to_csv(item6_path, index=False, encoding="utf-8-sig")
df_item5.to_csv(item5_path, index=False, encoding="utf-8-sig")

summary_results["spectrum_mapping"] = {
    "mapped_items": df_mapped,
    "spectrum6_table": df_item6,
    "spectrum5_table": df_item5,
    "spectrum6_csv": str(item6_path),
    "spectrum5_csv": str(item5_path),
}

print("Saved:", item6_path)
print("Saved:", item5_path)
df_mapped.head()

# %% [markdown]
# ## 7. Factor-level weighted aggregation
#
# The summary tables are saved as `../output/factor_radar6.csv` and `../output/factor_radar5.csv`.

# %%
def build_factor_radar_tables(df_mapped: pd.DataFrame) -> tuple[pd.DataFrame, pd.DataFrame]:
    """Aggregate seed-count weights within each Factor × spectrum category."""
    factor_radar6 = (
        df_mapped.dropna(subset=["spectrum6"])
        .groupby(["Factor", "spectrum6"])["seeds_count"]
        .sum()
        .unstack(fill_value=0)
        .reindex(columns=SPECTRA_6, fill_value=0)
        .sort_index()
    )
    factor_radar5 = (
        df_mapped.dropna(subset=["spectrum5"])
        .groupby(["Factor", "spectrum5"])["seeds_count"]
        .sum()
        .unstack(fill_value=0)
        .reindex(columns=SPECTRA_5, fill_value=0)
        .sort_index()
    )
    return factor_radar6, factor_radar5


factor_radar6, factor_radar5 = build_factor_radar_tables(df_mapped)

radar6_path = OUTPUT_DIR / "factor_radar6.csv"
radar5_path = OUTPUT_DIR / "factor_radar5.csv"

factor_radar6.to_csv(radar6_path, encoding="utf-8-sig")
factor_radar5.to_csv(radar5_path, encoding="utf-8-sig")

summary_results["factor_spectrum_profiles"] = {
    "factor_radar6": factor_radar6,
    "factor_radar5": factor_radar5,
    "factor_radar6_csv": str(radar6_path),
    "factor_radar5_csv": str(radar5_path),
}

print("Saved:", radar6_path)
print("Saved:", radar5_path)

factor_radar6

# %% [markdown]
# ## 8. Radar plots and stacked bar charts
#
# Figures are shown in the notebook and saved under `../output`.

# %%
def plot_radar_multi_factor(
    radar_df: pd.DataFrame,
    labels: list[str],
    title: str,
    output_path: Path,
    normalize: bool = True,
) -> Path:
    """Plot one radar figure with one line per factor and save it."""
    angles = np.linspace(0, 2 * np.pi, len(labels), endpoint=False)
    angles_closed = np.concatenate([angles, angles[:1]])

    fig, ax = plt.subplots(figsize=(7.4, 7.4), subplot_kw=dict(polar=True))
    cmap = plt.get_cmap("tab10")

    for i, (factor_name, row) in enumerate(radar_df.iterrows()):
        vals = row.values.astype(float)
        if normalize:
            total = vals.sum()
            if total > 0:
                vals = vals / total

        vals_closed = np.concatenate([vals, vals[:1]])
        ax.plot(angles_closed, vals_closed, linewidth=2, label=factor_name, color=cmap(i))
        ax.fill(angles_closed, vals_closed, alpha=0.12, color=cmap(i))

    ax.set_thetagrids(np.degrees(angles), labels)
    ax.set_title(title, y=1.10)
    ax.grid(True, alpha=0.35)
    ax.legend(loc="upper right", bbox_to_anchor=(1.35, 1.10), frameon=False, title="Factor")
    plt.tight_layout()
    plt.savefig(output_path, dpi=300, bbox_inches="tight")
    plt.show()
    return output_path


def plot_stacked_bar_factor(radar_df: pd.DataFrame, title: str, output_path: Path) -> Path:
    """Plot the Factor × spectrum stacked bar chart and save it."""
    ax = radar_df.plot(kind="bar", stacked=True, figsize=(10, 5))
    ax.set_title(title)
    ax.set_ylabel("Weighted count: sum of seeds_count")
    ax.set_xlabel("Factor")
    plt.xticks(rotation=0)
    plt.tight_layout()
    plt.savefig(output_path, dpi=300, bbox_inches="tight")
    plt.show()
    return output_path


radar6_fig = plot_radar_multi_factor(
    factor_radar6,
    SPECTRA_6,
    "Factor profiles on Spectrum-6: seeds_count-weighted and normalized",
    OUTPUT_DIR / "factor_profiles_spectrum6_radar.png",
    normalize=True,
)
radar5_fig = plot_radar_multi_factor(
    factor_radar5,
    SPECTRA_5,
    "Factor profiles on Spectrum-5: seeds_count-weighted and normalized",
    OUTPUT_DIR / "factor_profiles_spectrum5_radar.png",
    normalize=True,
)
bar6_fig = plot_stacked_bar_factor(
    factor_radar6,
    "Factor × Spectrum-6 weighted counts",
    OUTPUT_DIR / "factor_by_spectrum6_weighted_bar.png",
)
bar5_fig = plot_stacked_bar_factor(
    factor_radar5,
    "Factor × Spectrum-5 weighted counts",
    OUTPUT_DIR / "factor_by_spectrum5_weighted_bar.png",
)

summary_results["figures"] = {
    "frequency_contour_terrain": str(contour_path),
    "spectrum6_radar": str(radar6_fig),
    "spectrum5_radar": str(radar5_fig),
    "spectrum6_stacked_bar": str(bar6_fig),
    "spectrum5_stacked_bar": str(bar5_fig),
}

print("Saved figures:")
for name, path in summary_results["figures"].items():
    print(f"- {name}: {path}")

# %% [markdown]
# ## 9. Final organized result dictionary and output summary
#
# `summary_results` collects the main tables, metadata, and figure paths generated by this notebook. This is the unified result object for this notebook's seed-summary analysis.

# %%
output_summary = pd.DataFrame(
    [
        {"output_name": "factor_top_items_across_seeds", "type": "csv", "path": str(CSV_PATH)},
        {"output_name": "items_to_spectrum6", "type": "csv", "path": str(item6_path)},
        {"output_name": "items_to_spectrum5", "type": "csv", "path": str(item5_path)},
        {"output_name": "factor_radar6", "type": "csv", "path": str(radar6_path)},
        {"output_name": "factor_radar5", "type": "csv", "path": str(radar5_path)},
        {"output_name": "frequency_contour_terrain", "type": "png", "path": str(contour_path)},
        {"output_name": "factor_profiles_spectrum6_radar", "type": "png", "path": str(radar6_fig)},
        {"output_name": "factor_profiles_spectrum5_radar", "type": "png", "path": str(radar5_fig)},
        {"output_name": "factor_by_spectrum6_weighted_bar", "type": "png", "path": str(bar6_fig)},
        {"output_name": "factor_by_spectrum5_weighted_bar", "type": "png", "path": str(bar5_fig)},
    ]
)

summary_results["output_summary"] = output_summary

print("All notebook outputs are saved to:", OUTPUT_DIR)
output_summary
